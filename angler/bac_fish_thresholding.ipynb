# %%
from __future__ import print_function
# %matplotlib inline

from skimage.io import imread as imread
import skimage.io as io
import os
from skimage import morphology as morph
import matplotlib.pyplot as plt
import numpy as np

# %%
img=imread("/Users/omidalam/Box_Sync/Andy_lab/Projects/tsa_compaction/"+
             "3_oligo_library/fish_analysis/crop_sample/HCT116_Lib9-A488_lib10-A594_2_visit_1_D3D_ALX_PRJ0.tif")
pln,ch,row,col=img.shape

from oligo_lib_functions import im_prj
prj=im_prj(img[:,1,:,:],z_ind=0)

prj.shape
# Out:
# (32, 43)

# %%
io.imshow(prj)

# %%
def prj_3d_plottr(prj,TH):    
    from mpl_toolkits.mplot3d import Axes3D
    import matplotlib.pyplot as plt
    from matplotlib import cm
    from matplotlib.ticker import LinearLocator, FormatStrFormatter
    import numpy as n

    fig = plt.figure(figsize=(15,10))
    ax = fig.gca(projection='3d')

    # Make data.
    X,Y=prj.shape
    X = np.arange(0, X, 1)
    Y = np.arange(0, Y, 1)
    X, Y = np.meshgrid(Y, X)

    prj2=prj.copy()
    # TH=1000
    prj2[prj>TH]=TH
    # Plot the surface.
    surf = ax.plot_surface(X, Y, prj2, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    ax.set_zlim(0, TH)
    # ax.zaxis.set_major_locator(LinearLocator(10))
    # ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

    # Add a color bar which maps values to colors.
    fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
prj_3d_plottr(prj,1000)

# %%
num_bins = 10
plt.hist(prj.ravel(), bins=100)
plt.show()

# %%
def img_thresholder(img,thresh):
    img2[:]=
    img[img<thresh]=0
    return(1)
img_thresholder(prj,10000)
# io.imshow(img_thresholder(prj,10000))
# prj[prj<10000].reshape(prj.shape)
# io.imshow(prj[prj<10000])
# io.imshow(prj[prj>mask])
# io.imshow(prj[prj>np.full_like(prj,2000)])
# Out:
# 1

# %%
io.imshow(prj)

# %%
x=np.zeros((2,4))
y=x
y[1,0]=1

# %%
y?
